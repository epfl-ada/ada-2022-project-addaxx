# %%
import pandas as pd
import numpy as np
import wikidata

# scraping libraries
from bs4 import BeautifulSoup
from wikidata.client import Client

# %%
# import the data
df = pd.read_csv('top_20_communities_all_actors_wikidata.csv')

# %%
df
# Out:
#                 Actor_name  connectivity actor_gender Actor_date_of_birth  \
# 0               John Wayne           286            M          1907-05-26
# 1               Roy Rogers           242            M          1911-11-05
# 2     George 'Gabby' Hayes           130            M          1885-05-07
# 3           Basil Rathbone           121            M          1892-06-13
# 4           John Carradine           114            M          1906-02-05
# ...                    ...           ...          ...                 ...
# 6069           Pushpavalli             3            F                 NaN
# 6070               Sarathi             3            M          1942-06-26
# 6071                Ragini             3            F                1937
# 6072            Nirmalamma             3            F                1920
# 6073        Rushyendramani             3            F          1917-01-01
#
#      Actor_ethnicity Freebase_actor_ID  community Wikidata_actor_id
# 0          /m/063k3h          /m/043gj          1            Q40531
# 1          /m/07hwkr        /m/01mc6h1          1           Q367129
# 2                NaN         /m/03l6jx          1          Q1277973
# 3                NaN          /m/0hwd8          1           Q336865
# 4                NaN         /m/021mlp          1           Q312878
# ...              ...               ...        ...               ...
# 6069             NaN        /m/080hxfv         20          Q7261853
# 6070             NaN        /m/0463_8t         20          Q7423331
# 6071             NaN        /m/06w4wmq         20          Q7283094
# 6072             NaN        /m/07kj3f9         20          Q7040057
# 6073             NaN        /m/0br_7d6         20          Q7380893
#
# [6074 rows x 8 columns]

# %%
# create a new client
client = Client()

# %%
# function that gets the actor description from the wikidata id (if an error occurs, it returns 'NaN')
def get_actor_description(wikidata_id):
    try:
        actor = client.get(wikidata_id, load=True)
        return actor.description.texts['en']
    except:
        return np.nan

# %%
def get_actor_country_of_citizenship(wikidata_id):
    try:
        actor = client.get(wikidata_id, load=True)
        citizenship_prop = client.get('P27')
        citizenship = actor[citizenship_prop]
        return str(citizenship.label)
    except:
        return np.nan

# %%
# actor = client.get('Q1971717', load=True)
# citizenship_prop = client.get('P27')
# citizenship = actor[citizenship_prop]
# str(citizenship.label)
# get_actor_occupation('Q1971717')

# %%
def get_actor_occupation(wikidata_id):
    try:
        actor = client.get(wikidata_id, load=True)
        occupation_prop = client.get('P106')
#         occupation = actor[occupation_prop]
#         return occupation.label
        return [str(c.label) for c in actor.getlist(occupation_prop)]
    except:
        return np.nan

# %%
# sample test
df_Sample = df.sample(10)
df_Sample['actor_description'] = df_Sample['Wikidata_actor_id'].apply(get_actor_description)
df_Sample['actor_country_of_citizenship'] = df_Sample['Wikidata_actor_id'].apply(get_actor_country_of_citizenship)
df_Sample['actor_occupation'] = df_Sample['Wikidata_actor_id'].apply(get_actor_occupation)
df_Sample
# Out:
#                 Actor_name  connectivity actor_gender Actor_date_of_birth  \
# 4449          Hung Yan Yan             9            M          1965-02-25
# 3489  Poornam Vishwanathan            20            M                1921
# 3048       Morris Chestnut             8            M          1969-01-01
# 4661        Georgie Henley            18            F          1995-07-09
# 3124      Mariel Hemingway             6            F          1961-11-22
# 2380       David Tomlinson            25            M          1917-05-07
# 4893          Rachel Weisz             7            F          1970-03-07
# 4107        Angelina Jolie            19            F          1975-06-04
# 842        Ruth Chatterton             3            F          1892-12-24
# 3846        Millie Perkins             6            F          1938-05-12
#
#      Actor_ethnicity Freebase_actor_ID  community Wikidata_actor_id  \
# 4449             NaN        /m/064nh_q          9          Q3787623
# 3489             NaN        /m/04mxlwb          6          Q7228866
# 3048         /m/0x67          /m/0hqyy          5           Q472053
# 4661             NaN         /m/097c18         10           Q228875
# 3124             NaN         /m/02ldxr          5           Q234101
# 2380             NaN         /m/02w3kb          4           Q933980
# 4893       /m/013b6_         /m/014x77         11           Q134077
# 4107      /m/027n1m6         /m/0f4vbz          8            Q13909
# 842              NaN         /m/0173p_          1           Q287713
# 3846             NaN         /m/05v_f6          7           Q266512
#
#                  actor_description actor_country_of_citizenship  \
# 4449                         actor   People's Republic of China
# 3489                  Indian actor                        India
# 3048                American actor     United States of America
# 4661               English actress               United Kingdom
# 3124   American actress and author     United States of America
# 2380     English actor (1917-2000)               United Kingdom
# 4893               British actress               United Kingdom
# 4107  American actress (born 1975)     United States of America
# 842            actress (1892-1961)     United States of America
# 3846                       actress     United States of America
#
#                                        actor_occupation
# 4449                             [actor, film director]
# 3489                                            [actor]
# 3048  [actor, film producer, television actor, film ...
# 4661  [actor, child actor, stage actor, film actor, ...
# 3124  [actor, film actor, television actor, screenwr...
# 2380  [actor, stage actor, film actor, television ac...
# 4893  [television actor, film actor, film director, ...
# 4107  [film actor, film director, film producer, mod...
# 842   [stage actor, film actor, television actor, no...
# 3846       [actor, model, television actor, film actor]

# %%
# apply the function 
df['actor_description'] = df['Wikidata_actor_id'].apply(get_actor_description)
df['actor_country_of_citizenship'] = df['Wikidata_actor_id'].apply(get_actor_country_of_citizenship)
df['actor_occupation'] = df['Wikidata_actor_id'].apply(get_actor_occupation)

# %%
# save the data to a new csv file
# df.to_csv('top_20_communities_all_actors_wikidata_with_country_occupation.csv', index=False)
